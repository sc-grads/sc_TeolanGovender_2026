# %%
print ("Hello World")

print ("Shift + enter will also run he code")
# Out:
# Hello World
# Shift + enter will also run he code

# %%
print("CNTRL and left click allows you tp type in multiple lines")
print("CNTRL and left click allows you tp type in multiple lines")
print("CNTRL and left click allows you tp type in multiple lines")
print("CNTRL and left click allows you tp type in multiple lines")
print("CNTRL and left click allows you tp type in multiple lines")    #this is the last line
# Out:
# Shift and left click allows you tp type in multiple lines
# Shift and left click allows you tp type in multiple lines
# Shift and left click allows you tp type in multiple lines
# Shift and left click allows you tp type in multiple lines
# Shift and left click allows you tp type in multiple lines

# %%
100+20
