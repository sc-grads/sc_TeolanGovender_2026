# %%
var = 5
print(40/var)
print(40 //var)
print(40%var)
print(40 - (8*var))
# Out:
# 8.0
# 8
# 0
# 0

# %%
x,y,z = 25, 80, 9.5
type (z)

x_float = float (x)  #converts x into a float
(x_float)
# Out:
# 25.0

# %%
10 != 12
# Out:
# True

# %%
True or False # checks for a true
10==10 or 10<9
# Out:
# True

# %%
#chain comparison operator
24 >= 20 > 4 == 4 and 50 < 100 > 101
# Out:
# False

# %%
var = "hello world"
len(var)
# Out:
# 11

# %%
cat = "meow" ; dog = "woof" ; parrot="hello"
num = 3
print("My " + str(num) + " pets say " + cat, dog, parrot, sep = " AND ", end = "!!!") #string concatenation and conversion of int to string
dog.capitalize()
# Out:
# My 3 pets say meow AND woof AND hello!!!
# 'Woof'

# %%
"20"+"30"    #converts strings to ints
type(eval)
eval("20")+eval("30") == eval("70-20")
# Out:
# True

# %%
check = "aaaaaaaaaaaaaabbbbcccccccc"
check.count("a")      #counts the character 'a'
# Out:
# 14

# %%
messy = """\\PLEASE #@CLEAN UP-- #@THIS MESSY #@DOCSTRING WHICH --CAN HAVE\\ MULTIPLE LINES\\ OF STRING--"""
messy.replace("\\", "").replace("#@", "").replace("--", "")
# Out:
# 'PLEASE CLEAN UP THIS MESSY DOCSTRING WHICH CAN HAVE MULTIPLE LINES OF STRING'

# %%
pet = "Cat"
pet[2]
# Out:
# 't'
